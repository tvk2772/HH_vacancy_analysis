# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
data=[0.2,14,16,18]

fig = plt.figure(figsize=(6,4))
ax = fig.add_axes([0,0,1,1])

wedges, texts, autotexts = ax.pie(data, explode=[0.05,0.1,0.05,0.05], autopct='test', 
                                  textprops={'fontsize': 20, 'fontweight': 'bold', 'color': 'y'},
                                  labels=['L1', 'L2', 'L3', 'L4'], rotatelabels=True,
                                  startangle=45)

x = autotexts[0].get_position()[0]+0.3
y = autotexts[0].get_position()[1]
autotexts[0].set_position((x,y))

#bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          zorder=0, va="center")
ang = (wedges[0].theta2 - wedges[0].theta1)/2. + wedges[0].theta1
y = np.sin(np.deg2rad(ang))
x = np.cos(np.deg2rad(ang))
horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
connectionstyle = f"angle,angleA=0,angleB={ang}"
kw["arrowprops"].update({"connectionstyle": connectionstyle})
ax.annotate('Annotation', xy=(x,y), xytext=(1.35*np.sign(x), 1.4*y),
            horizontalalignment=horizontalalignment, **kw);
#ax.legend(wedges,data)

# %%
print('Wedges[1] properites:\n center: {}\ntheta1: {}\ntheta2: {}\nradius: {}'.format(
    wedges[1].center, wedges[1].theta1, wedges[1].theta2, wedges[1].r))

#print(texts)
# Out:
# Wedges[1] properites:
#  center: (0.029547230603439334, 0.040335606648061934)
# theta1: 1.493776012212038
# theta2: 106.05808513239026
# radius: 1

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = ["375 g flour",
          "75 g sugar",
          "250 g butter",
          "300 g berries"]

data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]


def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute:d} g)"


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, ingredients,
          title="Ingredients",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Matplotlib bakery: A pie")

plt.show()

for wedge, autotxt in zip(wedges, autotexts):
    print(wedge)
    print('(theta2-theta1) / 2: {}'.format((wedge.theta2-wedge.theta1)/2))
# Out:
# Wedge(center=(0, 0), r=1, theta1=0, theta2=135, width=None)
# (theta2-theta1) / 2: 67.5
# Wedge(center=(0, 0), r=1, theta1=135, theta2=162, width=None)
# (theta2-theta1) / 2: 13.500000536441803
# Wedge(center=(0, 0), r=1, theta1=162, theta2=252, width=None)
# (theta2-theta1) / 2: 45.0
# Wedge(center=(0, 0), r=1, theta1=252, theta2=360, width=None)
# (theta2-theta1) / 2: 54.00000214576721

# %%
fig, ax = plt.subplots()
x=1.0
y=1.0
x_txt=1.5
y_txt=1.5
arrowprops = dict(arrowstyle='-', connectionstyle="angle,angleA=45,rad=5")
ax.annotate('Annotation', xy=(x,y), xytext=(x_txt,y_txt), arrowprops=arrowprops);
# Out:
# Text(1.5, 1.5, 'Annotation')

# %%
fig, ax=plt.subplots(figsize=(12,3), facecolor='y')
